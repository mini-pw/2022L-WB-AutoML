# %% [markdown]
# ## Wyniki wszystkich zbiorow

# %%
import openml
import pandas as pd
import numpy as np
import os

# %%
folders = os.listdir('scores/')
folders.remove('.ipynb_checkpoints',)

# %%
wyniki = [0 for i in range(19)]
i=0
for file_name in folders:
    print('File:', file_name)
    data_file = 'scores/' + file_name
    score = pd.read_csv(data_file)
    wyniki[i] = score
    i+=1
# Out:
# File: 7592.csv
# File: 3945.csv
# File: 146606.csv
# File: 168911.csv
# File: 146818.csv
# File: 31.csv
# File: 168908.csv
# File: 189354.csv
# File: 14965.csv
# File: 34539.csv
# File: 167120.csv
# File: 3.csv
# File: 10101.csv
# File: 9977.csv
# File: 168868.csv
# File: 168912.csv
# File: 168335.csv
# File: 9952.csv
# File: 3917.csv

# %%
df0 = wyniki[0]
df0 = df0.drop(['models'], axis = 1)
df0['dataset'] = ['adult']*10
df0['time'] = ['(1800,450)']*10
df0
# Out:
#       score dataset        time
# 0  0.928182   adult  (1800,450)
# 1  0.925919   adult  (1800,450)
# 2  0.928795   adult  (1800,450)
# 3  0.924817   adult  (1800,450)
# 4  0.925229   adult  (1800,450)
# 5  0.921666   adult  (1800,450)
# 6  0.925627   adult  (1800,450)
# 7  0.928975   adult  (1800,450)
# 8  0.935775   adult  (1800,450)
# 9  0.931247   adult  (1800,450)

# %%
df1 = wyniki[1]
df1 = df1.drop(['models'], axis = 1)
df1['dataset'] = ['KDDCup09_appetency']*10
df1['time'] = ['(360,40)']*10
df1
# Out:
#       score             dataset      time
# 0  0.848446  KDDCup09_appetency  (360,40)
# 1  0.783456  KDDCup09_appetency  (360,40)
# 2  0.799782  KDDCup09_appetency  (360,40)
# 3  0.792621  KDDCup09_appetency  (360,40)
# 4  0.841920  KDDCup09_appetency  (360,40)
# 5  0.812679  KDDCup09_appetency  (360,40)
# 6  0.827242  KDDCup09_appetency  (360,40)
# 7  0.828319  KDDCup09_appetency  (360,40)
# 8  0.802894  KDDCup09_appetency  (360,40)
# 9  0.810940  KDDCup09_appetency  (360,40)

# %%
df2 = wyniki[2]
df2 = df2.drop(['models'], axis = 1)
df2['dataset'] = ['higgs']*10
df2['time'] = ['(1800,450)']*10
df2
# Out:
#       score dataset        time
# 0  0.814687   higgs  (1800,450)
# 1  0.800714   higgs  (1800,450)
# 2  0.809670   higgs  (1800,450)
# 3  0.810812   higgs  (1800,450)
# 4  0.812532   higgs  (1800,450)
# 5  0.809582   higgs  (1800,450)
# 6  0.813569   higgs  (1800,450)
# 7  0.799200   higgs  (1800,450)
# 8  0.796312   higgs  (1800,450)
# 9  0.817407   higgs  (1800,450)

# %%
df3 = wyniki[3]
df3 = df3.drop(['models'], axis = 1)
df3['dataset'] = ['jasmine']*10
df3['time'] = ['(360,40)']*10
df3
# Out:
#       score  dataset      time
# 0  0.860626  jasmine  (360,40)
# 1  0.887606  jasmine  (360,40)
# 2  0.906443  jasmine  (360,40)
# 3  0.873691  jasmine  (360,40)
# 4  0.883924  jasmine  (360,40)
# 5  0.868519  jasmine  (360,40)
# 6  0.884239  jasmine  (360,40)
# 7  0.865547  jasmine  (360,40)
# 8  0.887302  jasmine  (360,40)
# 9  0.887483  jasmine  (360,40)

# %%
df4 = wyniki[4]
df4 = df4.drop(['models'], axis = 1)
df4['dataset'] = ['Australian']*10
df4['time'] = ['(1800,450)']*10
df4
# Out:
#       score     dataset        time
# 0  0.937182  Australian  (1800,450)
# 1  0.920204  Australian  (1800,450)
# 2  0.921902  Australian  (1800,450)
# 3  0.926146  Australian  (1800,450)
# 4  0.957555  Australian  (1800,450)
# 5  0.977929  Australian  (1800,450)
# 6  0.901528  Australian  (1800,450)
# 7  0.927350  Australian  (1800,450)
# 8  0.965812  Australian  (1800,450)
# 9  0.905128  Australian  (1800,450)

# %%
df5 = wyniki[5]
df5 = df5.drop(['models'], axis = 1)
df5['dataset'] = ['credit-g']*10
df5['time'] = ['(1800,450)']*10
df5
# Out:
#       score   dataset        time
# 0  0.792857  credit-g  (1800,450)
# 1  0.776190  credit-g  (1800,450)
# 2  0.727619  credit-g  (1800,450)
# 3  0.753810  credit-g  (1800,450)
# 4  0.756667  credit-g  (1800,450)
# 5  0.799048  credit-g  (1800,450)
# 6  0.805238  credit-g  (1800,450)
# 7  0.810476  credit-g  (1800,450)
# 8  0.718095  credit-g  (1800,450)
# 9  0.766667  credit-g  (1800,450)

# %%
df6 = wyniki[6]
df6 = df6.drop(['models'], axis = 1)
df6['dataset'] = ['christine0']*10
df6['time'] = ['(360,40)']*10
df6
# Out:
#       score     dataset      time
# 0  0.816690  christine0  (360,40)
# 1  0.811039  christine0  (360,40)
# 2  0.809248  christine0  (360,40)
# 3  0.792024  christine0  (360,40)
# 4  0.797429  christine0  (360,40)
# 5  0.804625  christine0  (360,40)
# 6  0.804271  christine0  (360,40)
# 7  0.810644  christine0  (360,40)
# 8  0.796474  christine0  (360,40)
# 9  0.759608  christine0  (360,40)

# %%
df7 = wyniki[7]
df7 = df7.drop(['models'], axis = 1)
df7['dataset'] = ['airlines']*10
df7['time'] = ['(1800,450)']*10
df7
# Out:
#       score   dataset        time
# 0  0.671846  airlines  (1800,450)
# 1  0.672897  airlines  (1800,450)
# 2  0.674034  airlines  (1800,450)
# 3  0.677916  airlines  (1800,450)
# 4  0.671448  airlines  (1800,450)
# 5  0.670486  airlines  (1800,450)
# 6  0.676592  airlines  (1800,450)
# 7  0.669811  airlines  (1800,450)
# 8  0.670780  airlines  (1800,450)
# 9  0.675496  airlines  (1800,450)

# %%
df8 = wyniki[8]
df8 = df8.drop(['models'], axis = 1)
df8['dataset'] = ['bank-marketing']*10
df8['time'] = ['(360,40)']*10
df8
# Out:
#       score         dataset      time
# 0  0.937058  bank-marketing  (360,40)
# 1  0.933875  bank-marketing  (360,40)
# 2  0.940880  bank-marketing  (360,40)
# 3  0.936007  bank-marketing  (360,40)
# 4  0.937095  bank-marketing  (360,40)
# 5  0.928467  bank-marketing  (360,40)
# 6  0.926484  bank-marketing  (360,40)
# 7  0.941267  bank-marketing  (360,40)
# 8  0.935466  bank-marketing  (360,40)
# 9  0.944139  bank-marketing  (360,40)

# %%
df9 = wyniki[9]
df9 = df9.drop(['models'], axis = 1)
df9['dataset'] = ['Amazon_employee_access']*10
df9['time'] = ['(1800,450)']*10
df9
# Out:
#       score                 dataset        time
# 0  0.861779  Amazon_employee_access  (1800,450)
# 1  0.857306  Amazon_employee_access  (1800,450)
# 2  0.846084  Amazon_employee_access  (1800,450)
# 3  0.853659  Amazon_employee_access  (1800,450)
# 4  0.837178  Amazon_employee_access  (1800,450)
# 5  0.835222  Amazon_employee_access  (1800,450)
# 6  0.862871  Amazon_employee_access  (1800,450)
# 7  0.826429  Amazon_employee_access  (1800,450)
# 8  0.855578  Amazon_employee_access  (1800,450)
# 9  0.847875  Amazon_employee_access  (1800,450)

# %%
df10 = wyniki[10]
df10 = df10.drop(['models'], axis = 1)
df10['dataset'] = ['numerai28.6']*10
df10['time'] = ['(1800,450)']*10
df10
# Out:
#       score      dataset        time
# 0  0.523792  numerai28.6  (1800,450)
# 1  0.532392  numerai28.6  (1800,450)
# 2  0.524132  numerai28.6  (1800,450)
# 3  0.524423  numerai28.6  (1800,450)
# 4  0.532830  numerai28.6  (1800,450)
# 5  0.524582  numerai28.6  (1800,450)
# 6  0.528740  numerai28.6  (1800,450)
# 7  0.523453  numerai28.6  (1800,450)
# 8  0.529309  numerai28.6  (1800,450)
# 9  0.527715  numerai28.6  (1800,450)

# %%
df11 = wyniki[11]
df11 = df11.drop(['models'], axis = 1)
df11['dataset'] = ['kr-vs-kp']*10
df11['time'] = ['(360,40)']*10
df11
# Out:
#       score   dataset      time
# 0  0.999726  kr-vs-kp  (360,40)
# 1  0.998121  kr-vs-kp  (360,40)
# 2  0.998043  kr-vs-kp  (360,40)
# 3  1.000000  kr-vs-kp  (360,40)
# 4  1.000000  kr-vs-kp  (360,40)
# 5  1.000000  kr-vs-kp  (360,40)
# 6  0.999252  kr-vs-kp  (360,40)
# 7  0.996376  kr-vs-kp  (360,40)
# 8  0.999764  kr-vs-kp  (360,40)
# 9  1.000000  kr-vs-kp  (360,40)

# %%
df12 = wyniki[12]
df12 = df12.drop(['models'], axis = 1)
df12['dataset'] = ['blood-transfusion-service-center']*10
df12['time'] = ['(1800,450)']*10
df12
# Out:
#       score                           dataset        time
# 0  0.779727  blood-transfusion-service-center  (1800,450)
# 1  0.862086  blood-transfusion-service-center  (1800,450)
# 2  0.673489  blood-transfusion-service-center  (1800,450)
# 3  0.667154  blood-transfusion-service-center  (1800,450)
# 4  0.787524  blood-transfusion-service-center  (1800,450)
# 5  0.702242  blood-transfusion-service-center  (1800,450)
# 6  0.720760  blood-transfusion-service-center  (1800,450)
# 7  0.725634  blood-transfusion-service-center  (1800,450)
# 8  0.722910  blood-transfusion-service-center  (1800,450)
# 9  0.804438  blood-transfusion-service-center  (1800,450)

# %%
df13 = wyniki[13]
df13 = df13.drop(['models'], axis = 1)
df13['dataset'] = ['nomao']*10
df13['time'] = ['(360,40)']*10
df13
# Out:
#       score dataset      time
# 0  0.995524   nomao  (360,40)
# 1  0.994398   nomao  (360,40)
# 2  0.993408   nomao  (360,40)
# 3  0.994499   nomao  (360,40)
# 4  0.995713   nomao  (360,40)
# 5  0.995658   nomao  (360,40)
# 6  0.995735   nomao  (360,40)
# 7  0.994718   nomao  (360,40)
# 8  0.994780   nomao  (360,40)
# 9  0.995877   nomao  (360,40)

# %%
df14 = wyniki[14]
df14 = df14.drop(['models'], axis = 1)
df14['dataset'] = ['APSFailure']*10
df14['time'] = ['(1800,450)']*10
df14
# Out:
#       score     dataset        time
# 0  0.988994  APSFailure  (1800,450)
# 1  0.993325  APSFailure  (1800,450)
# 2  0.993237  APSFailure  (1800,450)
# 3  0.987742  APSFailure  (1800,450)
# 4  0.990317  APSFailure  (1800,450)
# 5  0.995784  APSFailure  (1800,450)
# 6  0.991196  APSFailure  (1800,450)
# 7  0.994433  APSFailure  (1800,450)
# 8  0.990065  APSFailure  (1800,450)
# 9  0.990667  APSFailure  (1800,450)

# %%
df15 = wyniki[15]
df15 = df15.drop(['models'], axis = 1)
df15['dataset'] = ['sylvine']*10
df15['time'] = ['(1800,450)']*10
df15
# Out:
#       score  dataset        time
# 0  0.977930  sylvine  (1800,450)
# 1  0.992765  sylvine  (1800,450)
# 2  0.988418  sylvine  (1800,450)
# 3  0.984512  sylvine  (1800,450)
# 4  0.988388  sylvine  (1800,450)
# 5  0.985107  sylvine  (1800,450)
# 6  0.990219  sylvine  (1800,450)
# 7  0.981964  sylvine  (1800,450)
# 8  0.990753  sylvine  (1800,450)
# 9  0.989990  sylvine  (1800,450)

# %%
df16 = wyniki[16]
df16 = df16.drop(['models'], axis = 1)
df16['dataset'] = ['MiniBooNE']*10
df16['time'] = ['(1800,450)']*10
df16
# Out:
#       score    dataset        time
# 0  0.968498  MiniBooNE  (1800,450)
# 1  0.986045  MiniBooNE  (1800,450)
# 2  0.985591  MiniBooNE  (1800,450)
# 3  0.986316  MiniBooNE  (1800,450)
# 4  0.986700  MiniBooNE  (1800,450)
# 5  0.985076  MiniBooNE  (1800,450)
# 6  0.987426  MiniBooNE  (1800,450)
# 7  0.985965  MiniBooNE  (1800,450)
# 8  0.986479  MiniBooNE  (1800,450)
# 9  0.987457  MiniBooNE  (1800,450)

# %%
df17 = wyniki[17]
df17 = df17.drop(['models'], axis = 1)
df17['dataset'] = ['phoneme']*10
df17['time'] = ['(360,40)']*10
df17
# Out:
#       score  dataset      time
# 0  0.965779  phoneme  (360,40)
# 1  0.973048  phoneme  (360,40)
# 2  0.964059  phoneme  (360,40)
# 3  0.956584  phoneme  (360,40)
# 4  0.951190  phoneme  (360,40)
# 5  0.969647  phoneme  (360,40)
# 6  0.976307  phoneme  (360,40)
# 7  0.962572  phoneme  (360,40)
# 8  0.956520  phoneme  (360,40)
# 9  0.963799  phoneme  (360,40)

# %%
df18 = wyniki[18]
df18 = df18.drop(['models'], axis = 1)
df18['dataset'] = ['kc1']*10
df18['time'] = ['(1800,450)']*10
df18
# Out:
#       score dataset        time
# 0  0.841480     kc1  (1800,450)
# 1  0.824197     kc1  (1800,450)
# 2  0.855010     kc1  (1800,450)
# 3  0.816905     kc1  (1800,450)
# 4  0.769663     kc1  (1800,450)
# 5  0.817501     kc1  (1800,450)
# 6  0.853081     kc1  (1800,450)
# 7  0.853592     kc1  (1800,450)
# 8  0.866020     kc1  (1800,450)
# 9  0.782128     kc1  (1800,450)

# %%
d = {'score' : 0.900215, 'dataset' : "guillermo",'time' :'(3600,900)'}
df19 = pd.DataFrame(data = d, index = [0])
df19
# Out:
#       score    dataset        time
# 0  0.900215  guillermo  (3600,900)

# %%
d = {'score' : 0.997814, 'dataset' : "riccardo",'time' :'(3600,900)'}
df20 = pd.DataFrame(data = d, index = [0])
df20
# Out:
#       score   dataset        time
# 0  0.997814  riccardo  (3600,900)

# %%
d = {'score' : [0.764265,0.761589,0.764980,0.761147,0.764253,0.761428,0.761447,0.767327,0.763582], 'dataset' : ["albert"]*9,'time' :'(3600,900)'}
df21 = pd.DataFrame(data = d, index = range(0,9,1))
df21
# Out:
#       score dataset        time
# 0  0.764265  albert  (3600,900)
# 1  0.761589  albert  (3600,900)
# 2  0.764980  albert  (3600,900)
# 3  0.761147  albert  (3600,900)
# 4  0.764253  albert  (3600,900)
# 5  0.761428  albert  (3600,900)
# 6  0.761447  albert  (3600,900)
# 7  0.767327  albert  (3600,900)
# 8  0.763582  albert  (3600,900)

# %%
df = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21])
df.index = range(len(df.index))
df.sort_values(by = 'score', axis=0, ascending=False, inplace=True, ignore_index=True)
df
# Out:
#         score      dataset        time
# 0    1.000000     kr-vs-kp    (360,40)
# 1    1.000000     kr-vs-kp    (360,40)
# 2    1.000000     kr-vs-kp    (360,40)
# 3    1.000000     kr-vs-kp    (360,40)
# 4    0.999764     kr-vs-kp    (360,40)
# ..        ...          ...         ...
# 186  0.524582  numerai28.6  (1800,450)
# 187  0.524423  numerai28.6  (1800,450)
# 188  0.524132  numerai28.6  (1800,450)
# 189  0.523792  numerai28.6  (1800,450)
# 190  0.523453  numerai28.6  (1800,450)
#
# [191 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
df.to_csv("plot_df.csv", index=False)

# %%
plt.figure(figsize=(12, 6))
groups = df.groupby('time')
for name, group in groups:
    plt.scatter(group.score, group.dataset, label=name)

plt.grid(axis = 'y', linestyle = '--', linewidth = 0.2)
plt.grid(axis = 'x', linewidth = 0.5)    
plt.legend(title = "Evalution time (fold, model)")
plt.xlabel("ROC_AUC")
plt.ylabel("Data set name")
plt.title("Auto-PyTorch results on OpenML data sets")
plt.savefig('results.png')

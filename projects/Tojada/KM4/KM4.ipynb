# %%
import autokeras as ak
from openml import datasets
from sklearn.metrics import accuracy_score,f1_score,roc_auc_score,recall_score,precision_score
from sklearn.model_selection import train_test_split, KFold
import pandas as pd
import numpy as np
import json
import time
from tensorflow.keras.models import load_model
import shutil
import os
# Out:
# 2022-06-08 21:38:19.756454: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-06-08 21:38:19.756543: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
def run(X : pd.DataFrame,y : pd.DataFrame, _del = True):
    start = time.time()
    
    kfold = KFold(n_splits=10, shuffle=True)
    clf = ak.StructuredDataClassifier(max_trials = 15) 
    
    best_acc = 0
    
    for fold, (train_index, test_index) in enumerate(kfold.split(X,y)):  # crossvalidation
          
        train_X, test_X = X.iloc[train_index], X.iloc[test_index]
        train_y, test_y = y.iloc[train_index], y.iloc[test_index]
        
        clf.fit(train_X, train_y, epochs = 100)
        prediction = pd.DataFrame(clf.predict(test_X))
        test_y = test_y.apply(pd.to_numeric, errors='coerce').fillna(test_y) # problems with types...
        prediction = prediction.apply(pd.to_numeric, errors='coerce').fillna(prediction)  
        
        
        acc = accuracy_score(test_y, prediction)
        
        
        if acc > best_acc:
            best_acc = acc
            best_model = clf


    
    end = time.time()
    execution_time = end - start
    
    return clf, scores_dict, execution_time

# %%
df_train = pd.read_csv('df_1_train.csv', index_col = 0)
df_test = pd.read_csv('df_1_test.csv',index_col = 0)

# %%
df_train['Y'] = df_train['Y'].map({"Bad":0,"Good":1})  # bez mapowania nie ogarnia niektórych metryk

# %%
y = df_train['Y']
X = df_train.drop(columns = 'Y')

# %%
clf, scores_dict, execution_time = run(X,y,_del = False)
# Out:
# Trial 15 Complete [00h 00m 38s]
# val_accuracy: 0.7236841917037964
#
# Best val_accuracy So Far: 0.7329721450805664
# Total elapsed time: 00h 11m 47s
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.6275 - accuracy: 0.6694
# Epoch 2/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5701 - accuracy: 0.7152
# Epoch 3/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5602 - accuracy: 0.7182
# Epoch 4/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5545 - accuracy: 0.7251
# Epoch 5/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.5514 - accuracy: 0.7217
# Epoch 6/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5477 - accuracy: 0.7271
# Epoch 7/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5454 - accuracy: 0.7294
# Epoch 8/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.5433 - accuracy: 0.7309
# Epoch 9/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5414 - accuracy: 0.7346
# Epoch 10/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5391 - accuracy: 0.7316
# Epoch 11/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5405 - accuracy: 0.7280
# Epoch 12/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5363 - accuracy: 0.7364
# Epoch 13/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5372 - accuracy: 0.7309
# Epoch 14/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5346 - accuracy: 0.7381
# Epoch 15/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.5339 - accuracy: 0.7370
# Epoch 16/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5330 - accuracy: 0.7376
# Epoch 17/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5326 - accuracy: 0.7352
# Epoch 18/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5311 - accuracy: 0.7432
# Epoch 19/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5305 - accuracy: 0.7402
# Epoch 20/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5296 - accuracy: 0.7396
# Epoch 21/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5289 - accuracy: 0.7407
# Epoch 22/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.5278 - accuracy: 0.7404
# Epoch 23/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5290 - accuracy: 0.7357
# Epoch 24/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5263 - accuracy: 0.7441
# Epoch 25/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5260 - accuracy: 0.7405
# Epoch 26/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5254 - accuracy: 0.7404
# Epoch 27/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5247 - accuracy: 0.7408
# Epoch 28/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5250 - accuracy: 0.7367
# Epoch 29/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5236 - accuracy: 0.7431
# Epoch 30/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5230 - accuracy: 0.7395
# Epoch 31/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5223 - accuracy: 0.7443
# Epoch 32/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.5218 - accuracy: 0.7431
# Epoch 33/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5212 - accuracy: 0.7441
# Epoch 34/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5207 - accuracy: 0.7440
# Epoch 35/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5210 - accuracy: 0.7367
# Epoch 36/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5197 - accuracy: 0.7444
# Epoch 37/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.5191 - accuracy: 0.7455
# Epoch 38/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5185 - accuracy: 0.7459
# Epoch 39/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5180 - accuracy: 0.7458
# Epoch 40/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5175 - accuracy: 0.7465
# Epoch 41/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5171 - accuracy: 0.7467
# Epoch 42/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5166 - accuracy: 0.7465
# Epoch 43/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5171 - accuracy: 0.7416
# Epoch 44/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5158 - accuracy: 0.7471
# Epoch 45/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.5155 - accuracy: 0.7473
# Epoch 46/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5151 - accuracy: 0.7477
# Epoch 47/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5147 - accuracy: 0.7483
# Epoch 48/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.5143 - accuracy: 0.7482
# Epoch 49/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5139 - accuracy: 0.7483
# Epoch 50/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5135 - accuracy: 0.7482
# Epoch 51/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5130 - accuracy: 0.7479
# Epoch 52/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5137 - accuracy: 0.7408
# Epoch 53/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5123 - accuracy: 0.7480
# Epoch 54/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5121 - accuracy: 0.7488
# Epoch 55/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5117 - accuracy: 0.7482
# Epoch 56/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.5113 - accuracy: 0.7485
# Epoch 57/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5110 - accuracy: 0.7488
# Epoch 58/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5107 - accuracy: 0.7491
# Epoch 59/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5100 - accuracy: 0.7489
# Epoch 60/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5097 - accuracy: 0.7495
# Epoch 61/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5102 - accuracy: 0.7444
# Epoch 62/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5091 - accuracy: 0.7498
# Epoch 63/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5088 - accuracy: 0.7505
# Epoch 64/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5085 - accuracy: 0.7503
# Epoch 65/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5081 - accuracy: 0.7514
# Epoch 66/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5080 - accuracy: 0.7512
# Epoch 67/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5075 - accuracy: 0.7520
# Epoch 68/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5072 - accuracy: 0.7529
# Epoch 69/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5069 - accuracy: 0.7529
# Epoch 70/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5066 - accuracy: 0.7538
# Epoch 71/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5062 - accuracy: 0.7547
# Epoch 72/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5070 - accuracy: 0.7477
# Epoch 73/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5055 - accuracy: 0.7542
# Epoch 74/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5053 - accuracy: 0.7544
# Epoch 75/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.5048 - accuracy: 0.7553
# Epoch 76/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5055 - accuracy: 0.7524
# Epoch 77/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5043 - accuracy: 0.7557
# Epoch 78/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5041 - accuracy: 0.7565
# Epoch 79/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.5038 - accuracy: 0.7575
# Epoch 80/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5036 - accuracy: 0.7577
# Epoch 81/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5033 - accuracy: 0.7578
# Epoch 82/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5028 - accuracy: 0.7583
# Epoch 83/100
# 208/208 [==============================] - 1s 5ms/step - loss: 0.5044 - accuracy: 0.7508
# Epoch 84/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5024 - accuracy: 0.7577
# Epoch 85/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.5023 - accuracy: 0.7584
# Epoch 86/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5020 - accuracy: 0.7592
# Epoch 87/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5018 - accuracy: 0.7586
# Epoch 88/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5015 - accuracy: 0.7584
# Epoch 89/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5013 - accuracy: 0.7578
# Epoch 90/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5011 - accuracy: 0.7586
# Epoch 91/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5007 - accuracy: 0.7586
# Epoch 92/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5019 - accuracy: 0.7508
# Epoch 93/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5003 - accuracy: 0.7581
# Epoch 94/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5002 - accuracy: 0.7578
# Epoch 95/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5000 - accuracy: 0.7580
# Epoch 96/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.4998 - accuracy: 0.7580
# Epoch 97/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.4991 - accuracy: 0.7590
# Epoch 98/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.4987 - accuracy: 0.7590
# Epoch 99/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.4986 - accuracy: 0.7587
# Epoch 100/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.4980 - accuracy: 0.7593
# INFO:tensorflow:Assets written to: ./structured_data_classifier/best_model/assets
# 24/24 [==============================] - 0s 4ms/step
# 2022-06-08 20:08:01.581645: W tensorflow/core/data/root_dataset.cc:200] Optimization loop failed: CANCELLED: Operation was cancelled
# 24/24 [==============================] - 0s 4ms/step
# 24/24 [==============================] - 0s 4ms/step
# 24/24 [==============================] - 0s 4ms/step
# 24/24 [==============================] - 0s 3ms/step
# 24/24 [==============================] - 0s 3ms/step
# 24/24 [==============================] - 0s 3ms/step
# 24/24 [==============================] - 0s 3ms/step
# 24/24 [==============================] - 0s 3ms/step
# 2022-06-08 20:08:23.482679: W tensorflow/core/data/root_dataset.cc:200] Optimization loop failed: CANCELLED: Operation was cancelled
# 24/24 [==============================] - 0s 4ms/step

# %%
def save_json(key,content):
    '''
    Zapisywanie wyników do jsona, żeby potem ich użyć w ipynb/prezentacji.
    '''
    with open("results.json","r") as f:
        loaded = json.load(f)
    
    loaded[key] = content
    
    with open("results.json", "w") as output:
        json.dump(loaded,output, indent=4)
    
    
def save_model(clf,dataset_name):
    model = clf.export_model()
    try:
        model.save("models/model_" + dataset_name , save_format="tf")
    except Exception:
        model.save("models/model_" + dataset_name + ".h5")

# %%
save_model(clf = clf,dataset_name = "df_1_train")
save_json("df_1_train",{"scores" : scores_dict, "time" : execution_time})
# Out:
# INFO:tensorflow:Assets written to: models/model_df_1_train/assets

# %% [markdown]
# Teraz, żeby dostać coś takiego jak *example_submission.csv* w plikach na teamsach.

# %% [markdown]
# Model z autokeras w predict zwraca tylko labele, wiec trzeba troche naokolo zeby miec probabilities.

# %%
model_export = clf.export_model()
prob = model_export.predict(df_test)

# %%
wynik = pd.DataFrame(columns = ["row_id", "prob"]) 
wynik["row_id"] = list(df_test.index)
wynik["prob"] = prob

# %%
wynik
# Out:
#       row_id      prob
# 0          2  0.091264
# 1          3  0.232570
# 2          6  0.063990
# 3          9  0.206592
# 4         14  0.525718
# ...      ...       ...
# 3080   10442  0.755324
# 3081   10448  0.854341
# 3082   10452  0.722011
# 3083   10453  0.936571
# 3084   10458  0.790529
#
# [3085 rows x 2 columns]

# %%
wynik.to_csv("submission.csv")

# %% [markdown]
# Spr czy moze lepsze wyniki da jesli sie bedzie usuwac folder structured_data...

# %%
clf, scores_dict, execution_time = run(X,y,_del = True)
# Out:
# INFO:tensorflow:Reloading Oracle from existing project ./structured_data_classifier/oracle.json
# INFO:tensorflow:Reloading Tuner from ./structured_data_classifier/tuner0.json
# INFO:tensorflow:Oracle triggered exit

# %%
model_export = clf.export_model()
prob = model_export.predict(df_test)

# %%
wynik = pd.DataFrame(columns = ["row_id", "prob"]) 
wynik["row_id"] = list(df_test.index)
wynik["prob"] = prob

# %%
wynik.to_csv("submission.csv")

# %%
input_node = ak.StructuredDataInput()
output_node = ak.StructuredDataBlock(categorical_encoding=True, normalize = True)(input_node)
output_node = ak.DenseBlock()(output_node)
output_node = ak.ClassificationHead(num_classes = 2, metrics = 'roc_auc')(output_node)
clf = ak.AutoModel(
    inputs=input_node, outputs=output_node, overwrite=True, max_trials=10
)
clf.fit(x_train, y_train, epochs=100)
clf.predict(x_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 input_node = ak.StructuredDataInput()
#       2 output_node = ak.StructuredDataBlock(categorical_encoding=True)(input_node)
#
# NameError: name 'ak' is not defined

# %%
def run2(X : pd.DataFrame,y : pd.DataFrame):
    
    kfold = KFold(n_splits=10, shuffle=True)
    
    input_node = ak.StructuredDataInput()
    output_node = ak.StructuredDataBlock(categorical_encoding=True, normalize = True)(input_node)
    output_node = ak.DenseBlock()(output_node)
    output_node = ak.ClassificationHead(num_classes = 2, metrics = 'AUC')(output_node)
    clf = ak.AutoModel(
        inputs=input_node, outputs=output_node, overwrite=True, max_trials=10
    )
    
  
    best_auc = 0
    
    for fold, (train_index, test_index) in enumerate(kfold.split(X,y)):  # crossvalidation
        # if _del and os.path.isdir('structured_data_classifier'):
        #     shutil.rmtree(r'structured_data_classifier')
            
        
        train_X, test_X = X.iloc[train_index], X.iloc[test_index]
        train_y, test_y = y.iloc[train_index], y.iloc[test_index]
        
        clf.fit(train_X, train_y, epochs = 100)
        prediction = pd.DataFrame(clf.predict(test_X))
        test_y = test_y.apply(pd.to_numeric, errors='coerce').fillna(test_y) # problems with types...
        prediction = prediction.apply(pd.to_numeric, errors='coerce').fillna(prediction)  
        
        #scores
        
        auc = roc_auc_score(test_y,prediction)
        
        if auc > best_auc:
            best_auc = auc
            best_model = clf
    


    
    return best_model

# %%
df_train = pd.read_csv('df_1_train.csv', index_col = 0)
df_test = pd.read_csv('df_1_test.csv',index_col = 0)

# %%
df_train['Y'] = df_train['Y'].map({"Bad":0,"Good":1})  # bez mapowania nie ogarnia niektórych metryk

# %%
y = df_train['Y']
X = df_train.drop(columns = 'Y')

# %%
clf = run2(X,y)
# Out:
# Trial 10 Complete [00h 00m 31s]
# val_loss: 0.5561140775680542
#
# Best val_loss So Far: 0.5529577732086182
# Total elapsed time: 00h 05m 41s
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/100
# 208/208 [==============================] - 3s 8ms/step - loss: 0.6852 - auc: 0.6595
# Epoch 2/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.6384 - auc: 0.7005
# Epoch 3/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.6368 - auc: 0.7016
# Epoch 4/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.6358 - auc: 0.7063
# Epoch 5/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.6331 - auc: 0.7119
# Epoch 6/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.6291 - auc: 0.7172
# Epoch 7/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.6325 - auc: 0.7153
# Epoch 8/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.6308 - auc: 0.7154
# Epoch 9/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.6279 - auc: 0.7195
# Epoch 10/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.6240 - auc: 0.7234
# Epoch 11/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.6252 - auc: 0.7217
# Epoch 12/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.6215 - auc: 0.7265
# Epoch 13/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.6186 - auc: 0.7293
# Epoch 14/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.6220 - auc: 0.7273
# Epoch 15/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.6202 - auc: 0.7268
# Epoch 16/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.6183 - auc: 0.7311
# Epoch 17/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.6191 - auc: 0.7323
# Epoch 18/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.6155 - auc: 0.7343
# Epoch 19/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.6177 - auc: 0.7312
# Epoch 20/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.6166 - auc: 0.7298
# Epoch 21/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.6165 - auc: 0.7302
# Epoch 22/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.6154 - auc: 0.7320
# Epoch 23/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.6146 - auc: 0.7330
# Epoch 24/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.6105 - auc: 0.7382
# Epoch 25/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.6162 - auc: 0.7358
# Epoch 26/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.6111 - auc: 0.7379
# Epoch 27/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.6119 - auc: 0.7370
# Epoch 28/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.6154 - auc: 0.7363
# Epoch 29/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.6085 - auc: 0.7419
# Epoch 30/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.6095 - auc: 0.7422
# Epoch 31/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.6093 - auc: 0.7409
# Epoch 32/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.6078 - auc: 0.7402
# Epoch 33/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.6044 - auc: 0.7413
# Epoch 34/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.6104 - auc: 0.7408
# Epoch 35/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.6050 - auc: 0.7425
# Epoch 36/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.6036 - auc: 0.7461
# Epoch 37/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.6068 - auc: 0.7461
# Epoch 38/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.5997 - auc: 0.7471
# Epoch 39/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.6080 - auc: 0.7439
# Epoch 40/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.6012 - auc: 0.7505
# Epoch 41/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.6061 - auc: 0.7486
# Epoch 42/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.6046 - auc: 0.7453
# Epoch 43/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.6034 - auc: 0.7501
# Epoch 44/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.6006 - auc: 0.7490
# Epoch 45/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.6023 - auc: 0.7496
# Epoch 46/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.6017 - auc: 0.7461
# Epoch 47/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.5973 - auc: 0.7519
# Epoch 48/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.5993 - auc: 0.7515
# Epoch 49/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.6020 - auc: 0.7494
# Epoch 50/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.5930 - auc: 0.7580
# Epoch 51/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.5967 - auc: 0.7555
# Epoch 52/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.5997 - auc: 0.7521
# Epoch 53/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.5955 - auc: 0.7559
# Epoch 54/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.5923 - auc: 0.7577
# Epoch 55/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.6028 - auc: 0.7499
# Epoch 56/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.5922 - auc: 0.7583
# Epoch 57/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.5949 - auc: 0.7556
# Epoch 58/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.5913 - auc: 0.7619
# Epoch 59/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.5975 - auc: 0.7510
# Epoch 60/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.5936 - auc: 0.7573
# Epoch 61/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.5890 - auc: 0.7620
# Epoch 62/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.5896 - auc: 0.7595
# Epoch 63/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.5931 - auc: 0.7597
# Epoch 64/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.5944 - auc: 0.7564
# Epoch 65/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.5858 - auc: 0.7662
# Epoch 66/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.5887 - auc: 0.7601
# Epoch 67/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.5866 - auc: 0.7624
# Epoch 68/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.5867 - auc: 0.7650
# Epoch 69/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.5831 - auc: 0.7690
# Epoch 70/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.5831 - auc: 0.7628
# Epoch 71/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.5839 - auc: 0.7654
# Epoch 72/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.5901 - auc: 0.7635
# Epoch 73/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.5856 - auc: 0.7642
# Epoch 74/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.5899 - auc: 0.7589
# Epoch 75/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.5894 - auc: 0.7656
# Epoch 76/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.5820 - auc: 0.7682
# Epoch 77/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.5791 - auc: 0.7691
# Epoch 78/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.5836 - auc: 0.7658
# Epoch 79/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.5807 - auc: 0.7685
# Epoch 80/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.5858 - auc: 0.7684
# Epoch 81/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.5770 - auc: 0.7729
# Epoch 82/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.5934 - auc: 0.7622
# Epoch 83/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.5788 - auc: 0.7733
# Epoch 84/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.5744 - auc: 0.7727
# Epoch 85/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.5754 - auc: 0.7731
# Epoch 86/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.5767 - auc: 0.7728
# Epoch 87/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.5813 - auc: 0.7705
# Epoch 88/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.5820 - auc: 0.7672
# Epoch 89/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.5756 - auc: 0.7708
# Epoch 90/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.5758 - auc: 0.7780
# Epoch 91/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.5706 - auc: 0.7807
# Epoch 92/100
# 208/208 [==============================] - 1s 7ms/step - loss: 0.5734 - auc: 0.7764
# Epoch 93/100
# 208/208 [==============================] - 1s 6ms/step - loss: 0.5791 - auc: 0.7700
# Epoch 94/100
# 208/208 [==============================] - 2s 9ms/step - loss: 0.5740 - auc: 0.7732
# Epoch 95/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.5798 - auc: 0.7723
# Epoch 96/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.5761 - auc: 0.7776
# Epoch 97/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.5707 - auc: 0.7799
# Epoch 98/100
# 208/208 [==============================] - 2s 7ms/step - loss: 0.5806 - auc: 0.7729
# Epoch 99/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.5720 - auc: 0.7792
# Epoch 100/100
# 208/208 [==============================] - 2s 8ms/step - loss: 0.5740 - auc: 0.7775
# 2022-06-08 21:51:16.113436: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: ./auto_model/best_model/assets
# 24/24 [==============================] - 0s 3ms/step
# 24/24 [==============================] - 0s 4ms/step
# 24/24 [==============================] - 0s 4ms/step
# 24/24 [==============================] - 0s 4ms/step
# 24/24 [==============================] - 0s 4ms/step
# 24/24 [==============================] - 0s 4ms/step
# 24/24 [==============================] - 0s 4ms/step
# 24/24 [==============================] - 0s 4ms/step
# 24/24 [==============================] - 0s 4ms/step
# 24/24 [==============================] - 0s 3ms/step

# %%
model_export = clf.export_model()
prob = model_export.predict(df_test)

# %%
wynik = pd.DataFrame(columns = ["row_id", "prob"]) 
wynik["row_id"] = list(df_test.index)
wynik["prob"] = prob

# %%
wynik.to_csv("submission2.csv")
